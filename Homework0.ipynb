# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('D3.csv')
df.head()
M = len(df)
M
# Out:
# 100

# %%
X1 = df.values[:, 0]
Y = df.values[:, 3]
m = len(Y)
print('X1 = ', X1[: 5])
print('Y = ', Y[: 5])
print('m = ', m)
# Out:
# X1 =  [0.         0.04040404 0.08080808 0.12121212 0.16161616]
# Y =  [4.38754501 2.6796499  2.96848981 3.25406475 3.53637472]
# m =  100

# %%
X1 = df.values[:, 0]
Y = df.values[:, 3]
m = len(Y)
print('X1 = ', X1[: 100])
print('Y = ', Y[: 100])
print('m = ', m)
# Out:
# X1 =  [0.         0.04040404 0.08080808 0.12121212 0.16161616 0.2020202
#  0.24242424 0.28282828 0.32323232 0.36363636 0.4040404  0.44444444
#  0.48484848 0.52525252 0.56565657 0.60606061 0.64646465 0.68686869
#  0.72727273 0.76767677 0.80808081 0.84848485 0.88888889 0.92929293
#  0.96969697 1.01010101 1.05050505 1.09090909 1.13131313 1.17171717
#  1.21212121 1.25252525 1.29292929 1.33333333 1.37373737 1.41414141
#  1.45454546 1.49494949 1.53535354 1.57575758 1.61616162 1.65656566
#  1.6969697  1.73737374 1.77777778 1.81818182 1.85858586 1.8989899
#  1.93939394 1.97979798 2.02020202 2.06060606 2.1010101  2.14141414
#  2.18181818 2.22222222 2.26262626 2.3030303  2.34343434 2.38383838
#  2.42424242 2.46464646 2.5050505  2.54545455 2.58585859 2.62626263
#  2.66666667 2.70707071 2.74747475 2.78787879 2.82828283 2.86868687
#  2.90909091 2.94949495 2.98989899 3.03030303 3.07070707 3.11111111
#  3.15151515 3.19191919 3.23232323 3.27272727 3.31313131 3.35353535
# ...

# %%
plt.scatter(X1, Y, color='red', marker= '+')
plt.grid()
plt.rcParams["figure.figsize"] = (10, 6)
plt.xlabel('X1-Axis')
plt.ylabel('Y-Axis')
plt.title('Scatter plot of training data (Y v X1)')
# Out:
# Text(0.5, 1.0, 'Scatter plot of training data (Y v X1)')

# %%
X2 = df.values[:, 1]
Y = df.values[:, 3]
m = len(Y)
print('X2 = ', X2[: 100])
print('Y = ', Y[: 100])
print('m = ', m)
# Out:
# X2 =  [3.44       0.1349495  0.82989899 1.52484848 2.21979798 2.91474747
#  3.60969697 0.30464646 0.99959596 1.69454546 2.38949495 3.08444444
#  3.77939394 0.47434343 1.16929293 1.86424242 2.55919192 3.25414141
#  3.94909091 0.6440404  1.3389899  2.03393939 2.72888889 3.42383838
#  0.11878788 0.81373737 1.50868687 2.20363636 2.89858586 3.59353535
#  0.28848485 0.98343434 1.67838384 2.37333333 3.06828283 3.76323232
#  0.45818182 1.15313131 1.84808081 2.5430303  3.2379798  3.93292929
#  0.62787879 1.32282828 2.01777778 2.71272727 3.40767677 0.10262626
#  0.79757576 1.49252525 2.18747475 2.88242424 3.57737374 0.27232323
#  0.96727273 1.66222222 2.35717172 3.05212121 3.74707071 0.4420202
#  1.1369697  1.83191919 2.52686869 3.22181818 3.91676768 0.61171717
#  1.30666667 2.00161616 2.69656566 3.39151515 0.08646465 0.78141414
#  1.47636364 2.17131313 2.86626263 3.56121212 0.25616162 0.95111111
#  1.64606061 2.3410101  3.0359596  3.73090909 0.42585859 1.12080808
# ...

# %%
plt.scatter(X2, Y, color='purple', marker= '+')
plt.grid()
plt.rcParams["figure.figsize"] = (10, 6)
plt.xlabel('X2-Axis')
plt.ylabel('Y-Axis')
plt.title('Scatter plot of training data (Y v X2)')
# Out:
# Text(0.5, 1.0, 'Scatter plot of training data (Y v X2)')

# %%
X3 = df.values[:, 2]
m = len(Y)
print('X3 = ', X3[: 100])
print('Y = ', Y[: 100])
print('m = ', m)
# Out:
# X3 =  [0.44       0.88848485 1.3369697  1.78545454 2.23393939 2.68242424
#  3.13090909 3.57939394 0.02787879 0.47636364 0.92484849 1.37333333
#  1.82181818 2.27030303 2.71878788 3.16727273 3.61575758 0.06424242
#  0.51272727 0.96121212 1.40969697 1.85818182 2.30666667 2.75515152
#  3.20363636 3.65212121 0.10060606 0.54909091 0.99757576 1.44606061
#  1.89454546 2.3430303  2.79151515 3.24       3.68848485 0.1369697
#  0.58545455 1.03393939 1.48242424 1.93090909 2.37939394 2.82787879
#  3.27636364 3.72484848 0.17333333 0.62181818 1.07030303 1.51878788
#  1.96727273 2.41575758 2.86424242 3.31272727 3.76121212 0.20969697
#  0.65818182 1.10666667 1.55515151 2.00363636 2.45212121 2.90060606
#  3.34909091 3.79757576 0.24606061 0.69454545 1.1430303  1.59151515
#  2.04       2.48848485 2.9369697  3.38545454 3.83393939 0.28242424
#  0.73090909 1.17939394 1.62787879 2.07636364 2.52484849 2.97333333
#  3.42181818 3.87030303 0.31878788 0.76727273 1.21575758 1.66424242
# ...

# %%
plt.scatter(X3, Y, color='green', marker= '+')
plt.grid()
plt.rcParams["figure.figsize"] = (10, 6)
plt.xlabel('X3-Axis')
plt.ylabel('Y-Axis')
plt.title('Scatter plot of training data (Y v X3)')
# Out:
# Text(0.5, 1.0, 'Scatter plot of training data (Y v X3)')

# %%
X_1a = np.ones((m, 1))
X_1a[: 5]
# Out:
# array([[1.],
#        [1.],
#        [1.],
#        [1.],
#        [1.]])

# %%
X_1b = X1.reshape(m, 1)
X_1b[: 10]
# Out:
# array([[0.        ],
#        [0.04040404],
#        [0.08080808],
#        [0.12121212],
#        [0.16161616],
#        [0.2020202 ],
#        [0.24242424],
#        [0.28282828],
#        [0.32323232],
#        [0.36363636]])

# %%
X1 = np.hstack((X_1a, X_1b))
X1[: 5]
# Out:
# array([[1.        , 0.        ],
#        [1.        , 0.04040404],
#        [1.        , 0.08080808],
#        [1.        , 0.12121212],
#        [1.        , 0.16161616]])

# %%
theta1 = np.zeros(2)
theta1
# Out:
# array([0., 0.])

# %%
def compute_cost(X, Y, theta):
    predictions = X.dot(theta)
    errors = np.subtract(predictions, Y)
    sqrErrors = np.square(errors)
    J = 1 / (2 * m) * np.sum(sqrErrors)
    
    return J

# %%
cost1 = compute_cost(X1, Y, theta1)
print('The cost for given values of theta_0 and theta_1 for X1 =', cost1)
# Out:
# The cost for given values of theta_0 and theta_1 for X1 = 5.524438459196242

# %%
def gradient_descent(X, Y, theta, alpha, iterations):
    cost_history = np.zeros(iterations)
    
    for i in range(iterations):
        predictions = X.dot(theta)
        errors = np.subtract(predictions, Y)
        sum_delta = (alpha / m) * X.transpose().dot(errors);
        theta = theta - sum_delta;
        cost_history[i] = compute_cost(X, Y, theta)
    
    return theta, cost_history

# %%
theta1 = [0., 0.]
iterations = 1500;
alpha = 0.01;

# %%
theta1, cost_history1 = gradient_descent(X1, Y, theta1, alpha, iterations)
print('Final value of theta (for X1) =', theta1)
print('cost_history (for X1) =', cost_history1)
# Out:
# Final value of theta (for X1) = [ 5.71850653 -1.9568206 ]
# cost_history (for X1) = [5.48226715 5.44290965 5.40604087 ... 0.99063932 0.99061433 0.99058944]

# %%
plt.scatter(X1[:, 1], Y, color='red', marker= '+', label= 'Training Data (for X1)')
plt.plot(X1[:, 1], X1.dot(theta1), color='green', label='Linear Regression (for X1)')

plt.rcParams["figure.figsize"] = (10, 6)
plt.grid()
plt.xlabel('X1-Axis')
plt.ylabel('Y-Axis')
plt.title('Linear Regression Fit')
plt.legend()

# %%
X_2a = np.ones((m, 1))
X_2a[:5]
# Out:
# array([[1.],
#        [1.],
#        [1.],
#        [1.],
#        [1.]])

# %%
X_2b = X2.reshape(m, 1)
X_2b[:10]
# Out:
# array([[3.44      ],
#        [0.1349495 ],
#        [0.82989899],
#        [1.52484848],
#        [2.21979798],
#        [2.91474747],
#        [3.60969697],
#        [0.30464646],
#        [0.99959596],
#        [1.69454546]])

# %%
X2 = np.hstack((X_2a, X_2b))
X2[:5]
# Out:
# array([[1.        , 3.44      ],
#        [1.        , 0.1349495 ],
#        [1.        , 0.82989899],
#        [1.        , 1.52484848],
#        [1.        , 2.21979798]])

# %%
theta2 = np.zeros(2)
theta2
# Out:
# array([0., 0.])

# %%
cost2 = compute_cost(X2, Y, theta2)
print('The cost for given values of theta_0 and theta_1 for X2 =', cost2)
# Out:
# The cost for given values of theta_0 and theta_1 for X2 = 5.524438459196242

# %%
theta2 = [0., 0.]

# %%
theta2, cost_history2 = gradient_descent(X2, Y, theta2, alpha, iterations)
print('Final value of theta (for X2) =', theta2)
print('cost_history (for X2) =', cost_history2)
# Out:
# Final value of theta (for X2) = [0.71988473 0.56390334]
# cost_history (for X2) = [5.29831663 5.09909109 4.92356115 ... 3.5993997  3.59939955 3.5993994 ]

# %%
plt.scatter(X2[:,1], Y, color='purple', marker= '+', label= 'Training Data (for X2)')
plt.plot(X2[:,1], X2.dot(theta2), color='green', label='Linear Regression(for X2)')

plt.rcParams["figure.figsize"] = (10, 6)
plt.grid()
plt.xlabel('X2-Axis')
plt.ylabel('Y-Axis')
plt.title('Linear Regression Fit (for X2)')
plt.legend()

# %%
X_3a = np.ones((m, 1))
X_3a[:5]
# Out:
# array([[1.],
#        [1.],
#        [1.],
#        [1.],
#        [1.]])

# %%
X_3b = X3.reshape(m, 1)
X_3b[:10]
# Out:
# array([[0.44      ],
#        [0.88848485],
#        [1.3369697 ],
#        [1.78545454],
#        [2.23393939],
#        [2.68242424],
#        [3.13090909],
#        [3.57939394],
#        [0.02787879],
#        [0.47636364]])

# %%
X3 = np.hstack((X_3a, X_3b))
X3[:5]
# Out:
# array([[1.        , 0.44      ],
#        [1.        , 0.88848485],
#        [1.        , 1.3369697 ],
#        [1.        , 1.78545454],
#        [1.        , 2.23393939]])

# %%
theta3 = np.zeros(2)
theta3
# Out:
# array([0., 0.])

# %%
cost3 = compute_cost(X3, Y, theta3)
print('the cost for given values of theta_0 and theta_1 (for X3) =', cost3)
# Out:
# the cost for given values of theta_0 and theta_1 (for X3) = 5.524438459196242

# %%
theta3 = [0., 0.]

# %%
theta3, cost_history3 = gradient_descent(X3, Y, theta3, alpha, iterations)
print('Final value of theta (for X3) =', theta3)
print('cost_history (for X3) =', cost_history3)
# Out:
# Final value of theta (for X3) = [ 2.78048129 -0.48451631]
# cost_history (for X3) = [5.40768785 5.30397076 5.21178297 ... 3.63053597 3.6305311  3.63052625]

# %%
plt.scatter(X3[:,1], Y, color='blue', marker= '+', label= 'Training Data (for X3)')
plt.plot(X3[:,1], X3.dot(theta3), color='green', label='Linear Regression (for X3)')

plt.rcParams["figure.figsize"] = (10,6)
plt.grid()
plt.xlabel('X3-Axis')
plt.ylabel('Y-Axis')
plt.title('Linear Regression Fit (for X3)')
plt.legend()

# %%
plt.plot(range(1, iterations + 1), cost_history1, color='blue')
plt.rcParams["figure.figsize"] = (10,6)
plt.grid()
plt.xlabel('Number of Iterations')
plt.ylabel('Cost (J)')
plt.title('Convergence of gradient descent (for X1)')
# Out:
# Text(0.5, 1.0, 'Convergence of gradient descent (for X1)')

# %%
plt.plot(range(1, iterations + 1), cost_history2, color='green')
plt.rcParams["figure.figsize"] = (10,6)
plt.grid()
plt.xlabel('Number of Iterations')
plt.ylabel('Cost (J)')
plt.title('Convergence of gradient descent (for X2)')
# Out:
# Text(0.5, 1.0, 'Convergence of gradient descent (for X2)')

# %%
plt.plot(range(1, iterations + 1), cost_history3, color='red')
plt.rcParams["figure.figsize"] = (10,6)
plt.grid()
plt.xlabel('Number of Iterations')
plt.ylabel('Cost (J)')
plt.title('Convergence of gradient descent (for X3)')
# Out:
# Text(0.5, 1.0, 'Convergence of gradient descent (for X3)')

# %%
X_123 = df.values[:, (0, 1, 2)]
Y = df.values[:, 3]
m = len(Y)
print('X = ', X_123[:5])
print('Y = ', Y[:5])
print('m = ', m)
# Out:
# X =  [[0.         3.44       0.44      ]
#  [0.04040404 0.1349495  0.88848485]
#  [0.08080808 0.82989899 1.3369697 ]
#  [0.12121212 1.52484848 1.78545454]
#  [0.16161616 2.21979798 2.23393939]]
# Y =  [4.38754501 2.6796499  2.96848981 3.25406475 3.53637472]
# m =  100

# %%
X1 = df.values[:, 0]
X2 = df.values[:, 1]
X3 = df.values[:, 2]

# %%
plt.scatter(X1, Y, color='red', marker='+', label='Training Data (for X1)')
plt.scatter(X2, Y, color='green', marker='+', label='Training Data (for X2)')
plt.scatter(X3, Y, color='purple', marker='+', label='Training Data (for X3)')

plt.grid()
plt.rcParams["figure.figsize"] = (10,6)
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
plt.title('Scatter Plot of Training Data')
plt.legend()

# %%
X_0 = np.ones((m, 1))
X_0[:5]
# Out:
# array([[1.],
#        [1.],
#        [1.],
#        [1.],
#        [1.]])

# %%
X = X_123.reshape(m, 3)
X[:5]
# Out:
# array([[0.        , 3.44      , 0.44      ],
#        [0.04040404, 0.1349495 , 0.88848485],
#        [0.08080808, 0.82989899, 1.3369697 ],
#        [0.12121212, 1.52484848, 1.78545454],
#        [0.16161616, 2.21979798, 2.23393939]])

# %%
X_123 = np.hstack((X_0, X))
X_123[:5]
# Out:
# array([[1.        , 0.        , 3.44      , 0.44      ],
#        [1.        , 0.04040404, 0.1349495 , 0.88848485],
#        [1.        , 0.08080808, 0.82989899, 1.3369697 ],
#        [1.        , 0.12121212, 1.52484848, 1.78545454],
#        [1.        , 0.16161616, 2.21979798, 2.23393939]])

# %%
theta_123 = np.zeros(4)
theta_123
# Out:
# array([0., 0., 0., 0.])

# %%
cost_123 = compute_cost(X_123, Y, theta_123)
print('The cost for given values of theta_0 and theta_1 (for X1, X2, and X3 together) = ', cost_123)
# Out:
# The cost for given values of theta_0 and theta_1 (for X1, X2, and X3 together) =  5.524438459196242

# %%
theta_123 = [0., 0., 0., 0.]
Iterations = 1500;
alpha = 0.01;

# %%
theta_123, cost_history_123 = gradient_descent(X_123, Y, theta_123, alpha, Iterations)
print('Final value of theta (for X1, X2, and X3 together) =', theta_123)
print('cost_history (for X1, X2, and X3 together) = ', cost_history_123[-1])
# Out:
# Final value of theta (for X1, X2, and X3 together) = [ 4.15118728 -1.8394291   0.72473856 -0.09513266]
# cost_history (for X1, X2, and X3 together) =  0.8105104429083866

# %%
plt.scatter(X1, Y, color='red', marker='+', label='Training Data (for X1)')
plt.scatter(X2, Y, color='green', marker='+', label='Training Data (for X2)')
plt.scatter(X3, Y, color='purple', marker='+', label='Training Data (for X3)')
plt.plot(X_123[:,1], X_123.dot(theta_123), color='blue', label='Linear Regression')

plt.rcParams["figure.figsize"] = (10,6)
plt.grid()
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
plt.title('Linear Regression Fit')
plt.legend()

# %%
plt.plot(range(1, Iterations + 1), cost_history_123, color='orange')
plt.rcParams['figure.figsize'] = (10,6)
plt.grid()
plt.xlabel('Number of Iterations')
plt.ylabel('Cost (J)')
plt.title('Convergence of gradient descent')
# Out:
# Text(0.5, 1.0, 'Convergence of gradient descent')

# %%
prediction1 = theta_123[3]*(1) + theta_123[2]*(1) + theta_123[1]*(1)
prediction2 = theta_123[3]*(2) + theta_123[2]*(0) + theta_123[1]*(4)
prediction3 = theta_123[3]*(3) + theta_123[2]*(2) + theta_123[1]*(1)

# %%
print('The output at (1, 1, 1) = ', prediction1)
print('The output at (2, 0, 4) = ', prediction2)
print('The output at (3, 2, 1) = ', prediction3)
# Out:
# The output at (1, 1, 1) =  -1.209823200863598
# The output at (2, 0, 4) =  -7.5479817190157314
# The output at (3, 2, 1) =  -0.6753499681039365
